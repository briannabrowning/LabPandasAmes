# %%
# import pandas

import pandas as pd

# %%
# import pandas

import pandas as pd

# Question 1
# Download and load the Ames CSV file. Read the file into a Pandas DataFrame and display the first five rows.  

# set option to view all columns
pd.set_option('display.max_columns', None)

housing_df = pd.read_csv("/Users/briannabrowning/Desktop/pandas sheets/AmesHousing.csv")

df.head(5)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
# Question 2: print highest and lowest priced homes

# max_price = df['SalePrice'].max()
# print (f'Highest price: {max_price}')

# min_price = df['SalePrice'].min()
# print (f'Lowest price: {min_price}')

df.describe()

df_sorted = df.sort_values(by='SalePrice')
print(df_sorted.iloc[0], df_sorted.iloc[-1])
# Out:
# Order                   182
# PID               902207130
# MS SubClass              30
# MS Zoning                RM
# Lot Frontage           68.0
#                     ...
# Mo Sold                   6
# Yr Sold                2010
# Sale Type               WD
# Sale Condition      Abnorml
# SalePrice             12789
# Name: 181, Length: 82, dtype: object Order                  1768
# PID               528351010
# MS SubClass              60
# MS Zoning                RL
# Lot Frontage          104.0
#                     ...
# Mo Sold                   1
# Yr Sold                2007
# Sale Type               WD
# Sale Condition       Normal
# SalePrice            755000
# Name: 1767, Length: 82, dtype: object

# %%
# Question 3: How many categories does lot size have? 

df['Lot Shape'].nunique()
# Out:
# 4

# %%
# Question 4: What is the range of years for the house listings in the data? 

print(df['Yr Sold'].min(), df['Yr Sold'].max())
# Out:
# 2006 2010

# %%
# Question 5:  What is the total number of all homes sold in Ames for all years? 

df['PID'].count()
# Out:
# 2930

# %%
# Question 6:  How many nulls or NA are there in the Lot Frontage column? 


df['Lot Frontage'].isnull().sum()
# Out:
# 490

# %%
# Question 7:  How many items have a value in Alley and what is the total number of  NA in the column?

print(df['Alley'].count(), 
df ['Alley'].isnull ().sum())
# Out:
# 198 2732

# %%
# Question 8:  What are all the homes in Gilbert with Yr Sold being 2009 and 2010?

df[(df['Neighborhood'] == 'Gilbert') & df['Yr Sold'].isin([2009, 2010])]
# Out:
#      Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 4        5  527105010           60        RL          74.0     13830   Pave
# 5        6  527105030           60        RL          78.0      9978   Pave
# 9       10  527162130           60        RL          60.0      7500   Pave
# 10      11  527163010           60        RL          75.0     10000   Pave
# 11      12  527165230           20        RL           NaN      7980   Pave
# 12      13  527166040           60        RL          63.0      8402   Pave
# 13      14  527180040           20        RL          85.0     10176   Pave
# 16      17  527225035           50        RL         152.0     12134   Pave
# 18      19  527276150           20        RL         140.0     19138   Pave
# 51      52  528218150           20        RL         100.0     18494   Pave
# 54      55  528231020           80        RL          67.0     13300   Pave
# ...

# %%
# Question 9:  What is the count of homes sold in Gilbert with Yr Sold being 2010? 

df[(df['Neighborhood'] == 'Gilbert') & (df['Yr Sold'] == 2010)].count()
# Out:
# Order             15
# PID               15
# MS SubClass       15
# MS Zoning         15
# Lot Frontage      11
#                   ..
# Mo Sold           15
# Yr Sold           15
# Sale Type         15
# Sale Condition    15
# SalePrice         15
# Length: 82, dtype: int64

# %%
# Question 10:  Return the value of the third row, and fifth column.

df.iloc[2, 4]
# Out:
# 81.0

# %%
# Question 11:  Remake a new column from the SalePrice that includes data formatted with the $, and commas for the thousands/millions digits. 
# : is to start the format
# , to put in the commas

def format_price(price):
    return '${:,.0f}'.format(price)


# create new column with sale price
df['FormattedSalePrice'] = df['SalePrice'].apply(format_price)

# %%
# Question 12:   Output a dataframe with only SalePrice, Neighborhood, and Year Built

# change the Sale Price column to formatted Sale price
df['FormattedSalePrice'] = formatted_Sale_Price = df['SalePrice'].map('${:,}'.format)

newDataFrame = df[['FormattedSalePrice', 'Neighborhood', 'Year Built']]

# print the new DataFrame
print(newDataFrame)
# Out:
#      FormattedSalePrice Neighborhood  Year Built
# 0              $215,000        NAmes        1960
# 1              $105,000        NAmes        1961
# 2              $172,000        NAmes        1958
# 3              $244,000        NAmes        1968
# 4              $189,900      Gilbert        1997
# ...                 ...          ...         ...
# 2925           $142,500      Mitchel        1984
# 2926           $131,000      Mitchel        1983
# 2927           $132,000      Mitchel        1992
# 2928           $170,000      Mitchel        1974
# 2929           $188,000      Mitchel        1993
#
# [2930 rows x 3 columns]

# %%
# save the file
# set index to false so newDataFrame isn't an index

newDataFrame.to_csv("minimal_ames_housing.csv", index=False)

# %%
df_2 = df.dropna(subset=['price'])
df_2.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/10/w77pm23s02z1dqv28_3vt7640000gn/T/ipykernel_50983/113682943.py in ?()
# ----> 1 df_2 = df.dropna(subset=['price'])
#       2 df_2.info()
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6414             ax = self._get_axis(agg_axis)
#    6415             indices = ax.get_indexer_for(subset)
#    6416             check = indices == -1
#    6417             if check.any():
# -> 6418                 raise KeyError(np.array(subset)[check].tolist())
#    6419             agg_obj = self.take(indices, axis=agg_axis)
#    6420
#    6421         if thresh is not lib.no_default:
#
# KeyError: ['price']

# %%
# fillna(): fill our rows w mean, med, mode, etc

df.['price'].fillna()
# Out:
#   Cell In[40], line 3
#     df.['price'].fillna()
#        ^
# SyntaxError: invalid syntax

# %%
df_0 = df_info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df_0 = df_info()
#
# NameError: name 'df_info' is not defined

# %%
df_0 = df['price'].fillna(np.mean(df['price']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df_0 = df['price'].fillna(np.mean(df['price']))
#
# ...

# %%
import numpy as np

df['price'] = df['price'].fillna(np.mean(df['price']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 3
#       1 import numpy as np
# ...

# %%
# maybe we only care if price is missing
